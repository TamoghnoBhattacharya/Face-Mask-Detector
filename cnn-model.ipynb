# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3880.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3660.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4302.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1107.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/498.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3268.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2741.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3054.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5023.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4694.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1392.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/785.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4834.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4515.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1681.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2239.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3508.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1111.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4405.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4120.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2572.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2020.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/791.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/866.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1965.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5922.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1777.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3716.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1557.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2387.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3637.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2015.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/180.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5156.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1442.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2173.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4953.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5798.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/841.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4878.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2374.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3144.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5786.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5764.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3773.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3218.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4575.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2843.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5049.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2919.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4307.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4507.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4284.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4641.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5556.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4272.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4134.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3584.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3689.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5147.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4008.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1971.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4570.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2630.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2265.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1244.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2150.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1561.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3335.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3569.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4394.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5956.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4445.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2740.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4377.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1431.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5364.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3154.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1774.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1507.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1485.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4990.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3384.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4478.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2248.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2360.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/509.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1490.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1705.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/412.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5766.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1938.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5554.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1516.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1208.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/71.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/358.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4112.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5208.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2464.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1083.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4822.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2354.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4528.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5552.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2167.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1048.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3316.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1247.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3497.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2861.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2644.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4279.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3604.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4053.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3505.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/365.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/209.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4467.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2136.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2152.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1893.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1581.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4862.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3015.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/356.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5667.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2063.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3648.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1426.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5984.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5889.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3642.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4946.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3709.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4549.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4115.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4509.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/445.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2617.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3673.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/752.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2273.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3805.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2732.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4258.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1722.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3728.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4730.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3682.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4841.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2893.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3558.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5668.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/672.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4079.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5838.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2040.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5876.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1032.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/907.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2111.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2546.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/566.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1044.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2176.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5359.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4733.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2371.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1067.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5718.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5841.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5231.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2576.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2217.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1073.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2593.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1903.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5807.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4470.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4983.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/507.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2850.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2633.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3921.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4334.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/105.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2658.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/268.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2061.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5584.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4508.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5587.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4126.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3793.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/883.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4910.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/526.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/995.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4989.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4937.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1818.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3387.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2437.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2805.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3406.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/508.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2931.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5790.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2612.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4547.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1164.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4792.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/322.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/255.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3864.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/256.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5522.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/723.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2491.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4939.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2203.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2684.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/632.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3843.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5834.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3804.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3967.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1267.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2793.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2202.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/816.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/106.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4083.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1372.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5322.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2439.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2623.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2988.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2419.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3203.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4615.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3857.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1689.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4414.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3342.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/474.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4560.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3535.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2517.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5279.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2749.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4714.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2267.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4639.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/281.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/552.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2977.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4298.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5633.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1951.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/312.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5961.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/962.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3580.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/573.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5078.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2924.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3634.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4055.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3537.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1926.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4629.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4138.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2506.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1793.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2157.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1721.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3768.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3937.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3723.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1785.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2659.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2660.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1283.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1874.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3888.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5856.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5396.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5088.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3318.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1815.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/413.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2301.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2391.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2420.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5479.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1778.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1848.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2233.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2868.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/482.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5534.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5251.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/944.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5470.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5830.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1540.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1647.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4739.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3664.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/136.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4906.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2915.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3892.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2941.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5763.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4388.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/202.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/27.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4441.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3555.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5905.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4328.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4712.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1577.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2215.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1879.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4686.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2586.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3393.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2162.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1669.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5920.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/916.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3265.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4871.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1288.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5779.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3133.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/843.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/96.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3055.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1155.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4715.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5095.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2759.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4267.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/148.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5172.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4474.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1365.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5812.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2316.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4149.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4069.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5635.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1071.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3150.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1185.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2541.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2260.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4373.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5494.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2204.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4835.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2544.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/943.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3747.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/848.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5692.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5960.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/607.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1464.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/734.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5995.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3291.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2994.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/315.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4118.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4771.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1521.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1005.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4826.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4850.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4029.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3606.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2863.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4366.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3683.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2762.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4764.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2943.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2710.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2410.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1236.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3453.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4313.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1424.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1544.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/11.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3661.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4403.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/308.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5816.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2505.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2760.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5055.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1099.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2743.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2856.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/584.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3565.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4830.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3127.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/593.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1317.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1752.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2459.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2227.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5253.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4358.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1231.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4376.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2211.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3354.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5402.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3390.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4042.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2243.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4402.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5796.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3663.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4558.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/502.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4681.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3440.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3917.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4235.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1347.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/288.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4495.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3464.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2366.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2238.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2980.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5388.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/432.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5101.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1502.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2151.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/900.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2982.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4607.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/701.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2672.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2407.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5407.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/444.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/860.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3276.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3249.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/411.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5277.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5069.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5993.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5376.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1095.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3308.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2596.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2894.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2820.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/294.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4897.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/321.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5895.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/470.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/724.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5768.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5548.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5524.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4482.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2013.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4336.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5579.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2355.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/396.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5774.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1641.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5000.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/246.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4357.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2033.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3030.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3999.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5028.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5601.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1123.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3547.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2358.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3035.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2409.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1914.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2591.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4907.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1275.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3869.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/116.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/947.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4858.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/401.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1399.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1325.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3941.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4912.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2380.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/166.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3025.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5765.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2488.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5219.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/2631.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4137.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5135.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/4842.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5473.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/36.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1331.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1434.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3481.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3121.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3685.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5011.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1213.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1889.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3852.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5274.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3267.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/337.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5295.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3885.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/5349.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3690.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/3636.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/1226.png
# ...
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_238_7487062.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_114_3364673.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_123_9676024.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_678_5117780.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1374.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/155.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_725_3898100.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_383_1664054.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_260_8364221.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_773_9264172.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_427_6087315.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_481_7431791.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_85_4469742.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_441_1932841.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_223_6160672.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_784_4473431.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_457_2821064.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/747.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_728_496193.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_107_6784686.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/232.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_52_8715428.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1416.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1604.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1002.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_110_8567370.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_763_6505781.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_804_8605594.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_68_9711296.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_391_3408619.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_727_5161110.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_654_771908.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/800.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/83.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1572.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_580_2383475.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_87_429586.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_180_4100922.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_283_41847.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_122_5203134.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_350_8452092.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_106_6675239.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_36_248219.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/579.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_863_5258905.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_803_4661080.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_329_507832.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_778_6581674.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1764.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_275_2098720.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_292_9020744.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_702_8393723.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_648_1282958.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_702_7175504.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_14_3524233.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/384.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_860_3894617.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_374_8367574.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_821_6241055.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/431.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_310_621262.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_229_6187516.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_504_9511834.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1412.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_20_1833682.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/794.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_426_1060542.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_249_4198658.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1189.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_16_4823631.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_213_3727173.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_429_5899144.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_560_9002345.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_427_4846957.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_442_4431013.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_358_4474074.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_796_8095922.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_392_9173703.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_833_8634013.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_181_5284517.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_726_3130124.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_617_1779630.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_115_2711402.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/838.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/540.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_551_7034710.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1833.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1358.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_178_9249152.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_264_3012374.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/394.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_810_151971.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_418_9064306.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_511_7761345.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1827.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_361_717028.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_891_25420.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_356_7337301.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_774_5823290.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_96_7557617.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_437_5297943.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_415_1564436.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1003.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_831_5837469.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/68.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_391_691566.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_876_2889056.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_77_8651466.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/627.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/6.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/1599.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_192_8838930.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_767_5473498.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_15_2242694.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_271_797250.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_752_7637407.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_633_6388002.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_589_5152191.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_462_73745.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_151_1277309.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_292_5674502.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_521_3705314.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_213_8352860.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_308_4081364.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_252_3266786.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_387_4290791.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_318_3562134.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_36_1688695.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_553_1817592.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/421.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_270_7961872.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/237.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_550_5248882.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_560_1489576.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_393_2288416.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/569.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_721_4610762.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_827_1110266.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_123_2830652.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_679_5714490.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_755_9444296.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/583.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_885_6489537.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_440_7738924.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_65_5555273.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/804.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_747_5251280.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_891_9937320.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_513_5146302.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_544_9645351.png
# /kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation/WithMask/Augmented_582_6061028.png
# /kaggle/input/img-vid/download.jpg
# /kaggle/input/img-vid/haarcascade_upperbody.xml
# /kaggle/input/img-vid/health-coronavirus-southkorea.jpg
# /kaggle/input/img-vid/data_model.h5
# /kaggle/input/img-vid/haarcascade_frontalface_default.xml
# /kaggle/input/img-vid/haarcascade_eye.xml
# /kaggle/input/img-vid/haarcascade_mcs_mouth.xml
# /kaggle/input/img-vid/videoplayback.webm

# %%
import sys
import os
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# uncomment the following line if 'imutils' is not installed in your python kernel
# !{sys.executable} -m pip install imutils
import imutils
from imutils import paths


import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Dropout, Activation, MaxPooling2D, Flatten
from keras.models import Sequential, load_model
from keras.losses import categorical_crossentropy, binary_crossentropy
from keras.optimizers import Adam
from keras.utils import np_utils
from keras.regularizers import l2
from keras import regularizers
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.applications.mobilenet_v2 import preprocess_input
from keras.preprocessing.image import load_img
from keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer

import cv2
import time
import random
import shutil
# Out:
# Requirement already satisfied: imutils in /opt/conda/lib/python3.7/site-packages (0.5.3)

# %%
# Path to the folders containing images

data_path = '../input/face-mask-12k-images-dataset/Face Mask Dataset'
mask_path = '../input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithMask/'
nomask_path = '../input/face-mask-12k-images-dataset/Face Mask Dataset/Train/WithoutMask/'
test_path = '../input/face-mask-12k-images-dataset/Face Mask Dataset/Test/'
train_path = '../input/face-mask-12k-images-dataset/Face Mask Dataset/Train/'

# %%
# function to show images from the input path
def view(path):
    images = list()
    for img in random.sample(os.listdir(path),9):
        images.append(img)
    i = 0
    fig,ax = plt.subplots(nrows=3, ncols=3, figsize=(20,10))
    for row in range(3):
        for col in range(3):
            ax[row,col].imshow(cv2.imread(os.path.join(path,images[i])))
            i+=1

# %%
# sample images of people wearing masks
view(mask_path)

# %%
#sample images of people NOT wearning masks
view(nomask_path)

# %%
batch_size = 128 # Batch Size
epochs = 15  # Number of Epochs
img_size = 224

# %%
# train_datagen = ImageDataGenerator(
#         rescale=1./255,
#         shear_range=0.2,
#         zoom_range=0.2,
#         horizontal_flip=True)
# test_datagen = ImageDataGenerator(rescale=1./255)

# training_set = train_datagen.flow_from_directory(
#         'train',
#         target_size=(224,224),
#         batch_size=16 ,
#         class_mode='binary')

# test_set = test_datagen.flow_from_directory(
#         'test',
#         target_size=(224,224),
#         batch_size=16,
#         class_mode='binary')
# Data Augmentation to increase training dataset size 

train_datagen = ImageDataGenerator(
        rescale=1./255,
#         rotation_range=20,
#         shear_range=0.2,
#         zoom_range=0.2,
#         width_shift_range=0.2,
# 	      height_shift_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)


training_set = train_datagen.flow_from_directory(
        train_path,
        target_size=(img_size,img_size),
        batch_size=batch_size,
        class_mode='binary')


test_set = test_datagen.flow_from_directory(
        test_path,
        target_size=(img_size,img_size),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# Found 10000 images belonging to 2 classes.
# Found 992 images belonging to 2 classes.

# %%
model=Sequential()

model.add(Conv2D(32, 3, activation='relu', input_shape=(224, 224, 3), kernel_regularizer=regularizers.l1_l2(0.005)))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64, 3, activation='relu'))
model.add(MaxPooling2D(2,2))
          
model.add(Conv2D(128, 3, activation='relu'))
model.add(MaxPooling2D(2,2)) 
model.add(Dropout(0.3))

model.add(Conv2D(128, 3, activation='relu', padding='same'))
model.add(MaxPooling2D(2,2)) 

model.add(Flatten())
model.add(Dropout(0.3))
          
model.add(Dense(256, activation ='relu'))
model.add(Dense(128, activation ='relu'))
model.add(Dense(1, activation ='sigmoid'))         

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
#   File "<ipython-input-132-02184a009cd5>", line 4
#     model.add(MaxPooling2D(2,2))zz
#                                  ^
# SyntaxError: invalid syntax

# %%
# Optimization of the model is done via Adam optimizer
# Loss is measures in the form of Binary Categorical Cross Entropy as our output contains 2 classes, with_mask and without_mask

model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history=model.fit(training_set, epochs=epochs, validation_data=test_set)

# %%
plt.plot(history.history['loss'],'r',label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.xlabel('No. of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plotting the accuracy on validation set w.r.t the number of epochs
plt.plot(history.history['accuracy'],'r',label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
model.save('cnn_(2)_model.h5', history)

# %%
# import os
# import sys

# import numpy as np
# # import matplotlib.pyplot as plt
# # %matplotlib inline

# import keras
# from keras.models import load_model
# from keras.models import model_from_json


# import cv2
# import datetime
# # Importing the saved model from the IPython notebook
# mymodel=load_model('../input/img-vid/data_model.h5')

# # Importing the Face Classifier XML file containing all features of the face
# face_classifier=cv2.CascadeClassifier('../input/img-vid/haarcascade_frontalface_default.xml')

# filename = 'video1.avi'
# frames_per_second = 24.0
# res = '480p'
 
# # Set resolution for the video capture
# # Function adapted from https://kirr.co/0l6qmh
# def change_res(cap, width, height):
#     cap.set(3, width)
#     cap.set(4, height)

# # Standard Video Dimensions Sizes
# STD_DIMENSIONS =  {
#     "480p": (640, 480),
#     "720p": (1280, 720),
#     "1080p": (1920, 1080),
#     "4k": (3840, 2160),
# }


# # grab resolution dimensions and set video capture to it.
# def get_dims(cap, res='720p'):
#     width, height = STD_DIMENSIONS["480p"]
#     if res in STD_DIMENSIONS:
#         width,height = STD_DIMENSIONS[res]
#     ## change the current caputre device
#     ## to the resulting resolution
#     change_res(cap, width, height)
#     return width, height

# # Video Encoding, might require additional installs
# # Types of Codes: http://www.fourcc.org/codecs.php
# VIDEO_TYPE = {
#     'avi': cv2.VideoWriter_fourcc(*'XVID'),
#     #'mp4': cv2.VideoWriter_fourcc(*'H264'),
#     'mp4': cv2.VideoWriter_fourcc(*'XVID'),
# }

# def get_video_type(filename):
#     filename, ext = os.path.splitext(filename)
#     if ext in VIDEO_TYPE:
#       return  VIDEO_TYPE[ext]
#     return VIDEO_TYPE['avi']


# # To open a video via link to be inserted in the () of VideoCapture()
# # To open the web cam connected to your laptop/PC, write '0' (without quotes) in the () of VideoCapture()
# cap=cv2.VideoCapture(0)

# out = cv2.VideoWriter(filename, get_video_type(filename), 25, get_dims(cap, res))

# # fourcc = cv2.VideoWriter_fourcc(*'XVID') 
# # out = cv2.VideoWriter('output.avi', fourcc, 20.0, (640, 480))

# while cap.isOpened():
#     _,img=cap.read()
#     img=cv2.flip(img,1,1)

#     rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

#     # detect MultiScale / faces
#     faces = face_classifier.detectMultiScale(rgb, 1.3, 5)
    
#     color_dict={0:(0,255,0),1:(0,0,255)}
#     # Draw rectangles around each face
#     for (x, y, w, h) in faces:

#         #Save just the rectangle faces in SubRecFaces
#         face_img = rgb[y:y+w, x:x+w]

#         face_img=cv2.resize(face_img,(224,224))
#         face_img=face_img/255.0
#         face_img=np.reshape(face_img,(224,224,3))
#         face_img=np.expand_dims(face_img,axis=0)
#         faces = np.vstack([face_img])
#         faces = np.array(faces, dtype="float32")
        
#         pred=mymodel.predict_classes(face_img) 
#         _, accuracy=mymodel.predict(face_img)[0]
# #         print(pred)
#         if  pred[0]==0 and accuracy < 0.5:
#             cv2.putText(img,'MASK',(x,y-30),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2) 
#             cv2.putText(img,f'Accuracy (%): {(1-accuracy)*100:.2f}',(x,y-10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,255,0),2)
#             cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2) 
#         else:
#             cv2.putText(img,'NO MASK',(x,y-30),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),2)
#             cv2.putText(img,f'Accuracy (%): {accuracy*100:.2f}',(x,y-10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),2)
#             cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2) 
            
#         datet=str(datetime.datetime.now())
#         cv2.putText(img,datet,(400,450),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)

    
#     out.write(img)
    
#     # Show the image
#     cv2.imshow('LIVE DETECTION',img)
    
#     # if key 'q' is press then break out of the loop
#     if cv2.waitKey(1)==ord('q'):
#         break
    
# # Stop video
# cap.release()

# out.release()

# # Close all started windows
# cv2.destroyAllWindows()
